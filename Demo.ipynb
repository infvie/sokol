# %%
import pandas as pd

# %%
pd.read_csv('atbat.csv',index_col=0)
# Out:
#     away_team_runs  b b_height  batter  \
# 0                0  1      6-0  446359
# 1                0  1      6-2  545361
# 2                0  2      6-2  457708
# 3                0  0      6-2  459964
# 4                0  1      6-0  543760
# 5                0  2      6-0  476704
# 6                0  0     5-10  501981
# 7                0  3      6-5  621566
# 8                0  0      6-3  405395
# 9                0  1     5-10  594777
# 10               1  1      6-2  592743
# 11               1  1     5-10  472528
# 12               1  0      6-4  660271
# 13               2  1      6-0  455117
# 14               2  2      6-0  446359
# 15               2  1      6-3  572039
# 16               2  1      6-0  656305
# 17               2  2      6-0  518960
# 18               2  1     5-10  621471
# 19               2  0      6-2  459964
# 20               2  1      6-2  545361
# 21               2  2      6-2  457708
# 22               2  2      6-3  405395
# ...

# %%
pd.read_csv('pitch.csv',index_col=0)
# Out:
#             ax         ay         az  break_angle  break_length  break_y  cc  \
# 0   -19.911162  32.791492 -17.557766         43.7           5.8     23.7 NaN
# 1   -20.043108  30.911711 -18.780096         42.7           6.1     23.8 NaN
# 2   -21.510485  30.321994 -18.731107         44.4           6.0     23.8 NaN
# 3     4.974062  21.571764 -38.346692         -8.2          10.8     23.9 NaN
# 4   -20.172978  30.364878 -21.028992         40.9           6.1     23.8 NaN
# 5   -19.830780  31.121657 -20.898379         39.8           6.1     23.8 NaN
# 6    -7.686676  30.737312 -14.574052         26.5           3.6     23.8 NaN
# 7    -2.797113  26.849513 -20.606653          4.7           4.7     23.9 NaN
# 8   -20.805981  32.276540 -21.494239         41.3           6.3     23.8 NaN
# 9   -21.553022  31.824772 -19.598771         43.4           6.2     23.8 NaN
# 10  -21.394399  33.176547 -20.396947         43.3           6.4     23.8 NaN
# ...
